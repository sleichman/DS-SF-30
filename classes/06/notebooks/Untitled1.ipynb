# %%
import os

import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 10)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
df = pd.read_csv('/Users/samuelleichman/DS-SF-30/unit-project/dataset/Q107II.csv')

# %%
df
# Out:
#                     ShipDate OrderNumber        ItemCode  \
# 0      1/3/2007  12:00:00 AM    G0784135      0096 WHITE
# 1      1/3/2007  12:00:00 AM    G0792852      0096 WHITE
# 2      1/3/2007  12:00:00 AM  WEB0784998      0096 WHITE
# 3      1/3/2007  12:00:00 AM  WEB0786966      0096 WHITE
# 4      1/3/2007  12:00:00 AM  WEB0790371      0096 WHITE
# ...                      ...         ...             ...
# 6203  3/12/2007  12:00:00 AM    G0825669   C8224 NATURAL
# 6204   1/3/2007  12:00:00 AM    G0790232   C9518 OPALINE
# 6205  1/10/2007  12:00:00 AM    G0796690  C9803 ALUMINUM
# 6206  2/14/2007  12:00:00 AM    G0817437      P8764 NONE
# 6207  2/20/2007  12:00:00 AM    G0818455      P8764 NONE
#
#                                    ItemDescription  \
# 0          Nelson Saucer Pendant Lamp - Med, White
# 1          Nelson Saucer Pendant Lamp - Med, White
# 2          Nelson Saucer Pendant Lamp - Med, White
# 3          Nelson Saucer Pendant Lamp - Med, White
# ...

# %%
df.shape
# Out:
# (6208, 19)

# %%
df.columns
# Out:
# Index([u'ShipDate', u'OrderNumber', u'ItemCode', u'ItemDescription',
#        u'OrderLocation', u'SKUCode', u'Department', u'UnitsSold',
#        u'TotalNetRevenue', u'TotalCOGS', u'GrossMarginDollars',
#        u'GrossMarginPercent', u'CurrentAverageCost', u'CurrentRetailPriceEach',
#        u'Current_GM_Each', u'Class', u'Category', u'Sub_Class', u'Quarter'],
#       dtype='object')

# %%
df.isnull()
# Out:
#      ShipDate OrderNumber ItemCode ItemDescription OrderLocation   ...    \
# 0       False       False    False           False         False   ...
# 1       False       False    False           False         False   ...
# 2       False       False    False           False         False   ...
# 3       False       False    False           False         False   ...
# 4       False       False    False           False         False   ...
# ...       ...         ...      ...             ...           ...   ...
# 6203    False       False    False           False         False   ...
# 6204    False       False    False           False         False   ...
# 6205    False       False    False           False         False   ...
# 6206    False       False    False           False         False   ...
# 6207    False       False    False           False         False   ...
#
#      Current_GM_Each  Class Category Sub_Class Quarter
# 0              False  False    False     False   False
# ...

# %%
df.isnull().sum()
# Out:
# ShipDate            0
# OrderNumber         0
# ItemCode            0
# ItemDescription     0
# OrderLocation       0
#                    ..
# Current_GM_Each     0
# Class               0
# Category           43
# Sub_Class          43
# Quarter             0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 86

# %%
df.columns[df.isnull().sum() > 0]
# Out:
# Index([u'Category', u'Sub_Class'], dtype='object')

# %%
n = df.shape[0]

for column in df.columns:
    count = df[column].isnull().sum()
    if count > 0:
        print '{:10s} {:6d} {:3.0f}%'.format(column, count, 100. * count / n)
# Out:
# Category       43   1%
# Sub_Class      43   1%

# %%
df.dropna(axis = 1)
# Out:
#                     ShipDate OrderNumber        ItemCode  \
# 0      1/3/2007  12:00:00 AM    G0784135      0096 WHITE
# 1      1/3/2007  12:00:00 AM    G0792852      0096 WHITE
# 2      1/3/2007  12:00:00 AM  WEB0784998      0096 WHITE
# 3      1/3/2007  12:00:00 AM  WEB0786966      0096 WHITE
# 4      1/3/2007  12:00:00 AM  WEB0790371      0096 WHITE
# ...                      ...         ...             ...
# 6203  3/12/2007  12:00:00 AM    G0825669   C8224 NATURAL
# 6204   1/3/2007  12:00:00 AM    G0790232   C9518 OPALINE
# 6205  1/10/2007  12:00:00 AM    G0796690  C9803 ALUMINUM
# 6206  2/14/2007  12:00:00 AM    G0817437      P8764 NONE
# 6207  2/20/2007  12:00:00 AM    G0818455      P8764 NONE
#
#                                    ItemDescription  \
# 0          Nelson Saucer Pendant Lamp - Med, White
# 1          Nelson Saucer Pendant Lamp - Med, White
# 2          Nelson Saucer Pendant Lamp - Med, White
# 3          Nelson Saucer Pendant Lamp - Med, White
# ...

# %%
df.isnull().sum().sum()
# Out:
# 86

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6203    False
# 6204    False
# 6205    False
# 6206    False
# 6207    False
# dtype: bool

# %%
df[df.duplicated()]
# Out:
#                     ShipDate OrderNumber       ItemCode  \
# 140   2/14/2007  12:00:00 AM    G0817687     0096 WHITE
# 924    1/5/2007  12:00:00 AM    G0794204  0242 ALUMINUM
# 1216   1/8/2007  12:00:00 AM    G0794604     0322 WHITE
# 1514  3/19/2007  12:00:00 AM  WEB0831842    0411 SILVER
# 2864   3/4/2007  12:00:00 AM    G0824903     2370 WHITE
# ...                      ...         ...            ...
# 4826  1/11/2007  12:00:00 AM  WEB0785922   6996 CRYSTAL
# 4840  1/11/2007  12:00:00 AM    G0790804   6996 CRYSTAL
# 4841  1/11/2007  12:00:00 AM    G0790804   6996 CRYSTAL
# 4851  1/11/2007  12:00:00 AM    G0795172   6996 CRYSTAL
# 4852  1/11/2007  12:00:00 AM    G0795172   6996 CRYSTAL
#
#                               ItemDescription                   OrderLocation  \
# 140   Nelson Saucer Pendant Lamp - Med, White           200 - DWR Call Center
# 924              Tolomeo Floor Lamp, Aluminum            240 - Houston Studio
# ...

# %%
np.sort(df.ItemDescription.unique())
# Out:
# array(['AJ Eklipta - 13.7 in., White', 'AJ Eklipta - 8.7 in., White',
#        'AJ Floor Lamp, Black', 'AJ Floor Lamp, White',
#        'Agave - Flower Pendant, Clear', 'Agave Flower Bulb, None',
#        'Akari Freeform Column Floor Lamp, None',
#        'Akari Square Lantern Table Lamp, None',
#        'Arco Floor Lamp - Black Base, Black',
#        'Arco Floor Lamp - Shade, Steel Grey',
#        'Arco Floor Lamp - White Base, Steel Grey',
#        'Artichoke Lamp - Small, White OLD, White',
#        'Artichoke Lamp Small - Cord, White', 'Ball Lamp Pendant, White',
#        'Bossa Pendant, Black', 'Bourgie Table Lamp',
#        'Bourgie Table Lamp, Black (SPO)',
#        'Cellula Chandelier - 32 in. Rod, Aluminum',
#        'Cellula Chandelier - 32 in., Glass',
#        'Cellula Chandelier - 47 in.OLD, Glass', 'Cesta Lamp',
#        'Chameledeon LED Floor Lamp - 28 in., White',
#        'Chameledeon LED Floor Lamp - 40 in., White',
# ...

# %%
len(df.ItemDescription.unique())
# Out:
# 211

# %%
df['ItemDescription'] = df.ItemDescription.apply(lambda ItemDescription: ItemDescription.strip().upper())

# %%
df.ItemDescription
# Out:
# 0            NELSON SAUCER PENDANT LAMP - MED, WHITE
# 1            NELSON SAUCER PENDANT LAMP - MED, WHITE
# 2            NELSON SAUCER PENDANT LAMP - MED, WHITE
# 3            NELSON SAUCER PENDANT LAMP - MED, WHITE
# 4            NELSON SAUCER PENDANT LAMP - MED, WHITE
#                             ...
# 6203                GILDA FLOOR LAMP SHADE , NATURAL
# 6204                MIRANDOLINA - OPAL DOME, OPALINE
# 6205       CELLULA CHANDELIER - 32 IN. ROD, ALUMINUM
# 6206    NELSON LAMP CEILING PLATE AND HARDWARE, NONE
# 6207    NELSON LAMP CEILING PLATE AND HARDWARE, NONE
# Name: ItemDescription, dtype: object

# %%
len(df.ItemDescription.unique())
# Out:
# 211

# %%
df.describe()
# Out:
#              SKUCode    UnitsSold  Current_GM_Each
# count    6208.000000  6208.000000      6208.000000
# mean   175330.762081     1.546231        48.042295
# std     55928.174066     3.686147        25.266858
# min    101738.000000     1.000000      -231.140000
# 25%    113236.000000     1.000000        38.590000
# 50%    179508.000000     1.000000        45.270000
# 75%    222594.000000     2.000000        51.960000
# max    300490.000000   201.000000       735.600000

# %%
df.var()
# Out:
# SKUCode            3.127961e+09
# UnitsSold          1.358768e+01
# Current_GM_Each    6.384141e+02
# dtype: float64
