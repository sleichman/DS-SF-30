# %%
import os

import numpy as np

import pandas as pd
pd.set_option('display.max_rows', 10)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

import statsmodels.api as sm
import statsmodels.formula.api as smf

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

import scipy.stats as stats

# %%
def read_dataset():
    return pd.read_csv(os.path.join('..', 'datasets', 'dataset-07-zillow.csv'), index_col = 'ID')

df = read_dataset()

# %%
df[ ['Size', 'LotSize'] ]
# Out:
#               Size  LotSize
# ID
# 15063471     550.0      NaN
# 15063505    1430.0   2435.0
# 15063609    2040.0   3920.0
# 15064044    1060.0      NaN
# 15064257    1299.0      NaN
# ...            ...      ...
# 2124214951   264.0      NaN
# 2126960082   691.0      NaN
# 2128308939  1738.0   2299.0
# 2131957929  1048.0      NaN
# 2136213970   900.0      NaN
#
# [1000 rows x 2 columns]

# %%
def scale_variables(df):
    df.Size /= 10 ** 3 # Size in 1,000 sqft
    df.LotSize /= 10 ** 3 # Lot size in 1,000 sqft

scale_variables(df)

# %%
df[ ['Size', 'LotSize'] ]
# Out:
#              Size  LotSize
# ID
# 15063471    0.550      NaN
# 15063505    1.430    2.435
# 15063609    2.040    3.920
# 15064044    1.060      NaN
# 15064257    1.299      NaN
# ...           ...      ...
# 2124214951  0.264      NaN
# 2126960082  0.691      NaN
# 2128308939  1.738    2.299
# 2131957929  1.048      NaN
# 2136213970  0.900      NaN
#
# [1000 rows x 2 columns]

# %%
def Xy(df):
    X = df [['Size']] # X is a DataFrame
    
    y = df.SalePrice # y is a Series
    
    return X, y

X, y = Xy(df)

model = smf.OLS(y, X).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                         nan
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Tue, 10 Jan 2017   Prob (F-statistic):                nan
# Time:                        12:46:34   Log-Likelihood:                    nan
# No. Observations:                1000   AIC:                               nan
# Df Residuals:                    1000   BIC:                               nan
# Df Model:                          -1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Size              nan        nan        nan        nan           nan       nan
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                     nan
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                  nan
# Skew:                             nan   Prob(JB):                          nan
# Kurtosis:                         nan   Cond. No.                          nan
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
def Xy_2(df):
    df = df.dropna(subset = ['Size', 'SalePrice'])
    X = df[['Size']] # X is a DataFrame
    
    y = df.SalePrice # y is a Series
    
    return X, y

X, y = Xy_2(df)

model = smf.OLS(y, X).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.565
# Method:                 Least Squares   F-statistic:                     1255.
# Date:                Tue, 10 Jan 2017   Prob (F-statistic):          7.83e-177
# Time:                        12:49:08   Log-Likelihood:                -1689.6
# No. Observations:                 967   AIC:                             3381.
# Df Residuals:                     966   BIC:                             3386.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Size           0.8176      0.023     35.426      0.000         0.772     0.863
# ==============================================================================
# Omnibus:                     1830.896   Durbin-Watson:                   1.722
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3370566.094
# Skew:                          13.300   Prob(JB):                         0.00
# Kurtosis:                     291.005   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
def Xy_3(df):
    df = df.dropna(subset = ['Size','SalePrice'])
    
    X = df[['Size']] #X is a DataFrame
    X = sm.add_constant(X)
    
    y = df.SalePrice # y is a Series
    
    return X, y

X, y = Xy_3(df)

model = smf.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.236
# Model:                            OLS   Adj. R-squared:                  0.235
# Method:                 Least Squares   F-statistic:                     297.4
# Date:                Tue, 10 Jan 2017   Prob (F-statistic):           2.67e-58
# Time:                        12:58:33   Log-Likelihood:                -1687.9
# No. Observations:                 967   AIC:                             3380.
# Df Residuals:                     965   BIC:                             3390.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          0.1551      0.084      1.842      0.066        -0.010     0.320
# Size           0.7497      0.043     17.246      0.000         0.664     0.835
# ==============================================================================
# Omnibus:                     1842.865   Durbin-Watson:                   1.704
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3398350.943
# Skew:                          13.502   Prob(JB):                         0.00
# Kurtosis:                     292.162   Cond. No.                         4.40
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
predict_X = pd.DataFrame({'Size':[1.2, 1.4, 1.6]}, columns = ['Size'])
predict_X = sm.add_constant(predict_X)

# %%
predict_X
# Out:
#    const  Size
# 0      1   1.2
# 1      1   1.4
# 2      1   1.6

# %%
predict_y = model.predict(predict_X)

# %%
predict_y
# Out:
# array([ 1.05472548,  1.2046711 ,  1.35461672])

# %%
type(predict_y)
# Out:
# numpy.ndarray

# %%
model.params
# Out:
# const    0.155052
# Size     0.749728
# dtype: float64

# %%
type(model.params)
# Out:
# pandas.core.series.Series

# %%
model.params.Size
# Out:
# 0.74972809216405056

# %%
model.tvalues
# Out:
# const     1.842394
# Size     17.245775
# dtype: float64

# %%
model.pvalues
# Out:
# const    6.572416e-02
# Size     2.667697e-58
# dtype: float64

# %%
model.conf_int()
# Out:
#               0         1
# const -0.010102  0.320205
# Size   0.664415  0.835041

# %%
type(model.conf_int())
# Out:
# pandas.core.frame.DataFrame

# %%
model.conf_int(alpha = .05).\
    rename(columns = {0: '2.5%', 1: '97.5%'})
# Out:
#            2.5%     97.5%
# const -0.010102  0.320205
# Size   0.664415  0.835041

# %%
model.conf_int(alpha = .10).\
    rename(columns = {0: '5%', 1: '95%'})
# Out:
#              5%       95%
# const  0.016492  0.293612
# Size   0.678152  0.821304

# %%
stats.norm.cdf(1) - stats.norm.cdf(-1)
# Out:
# 0.68268949213708585

# %%
print "For normally distributed data:"
for z in [1, 1.65, 2, 3]:
    print "\t- {:3.2f}% of it is between +/- {:1.2f} sigma(s)".\
        format ((stats.norm.cdf(z) - stats.norm.cdf(-z)) * 100,z)
# Out:
# For normally distributed data:
# 	- 68.27% of it is between +/- 1.00 sigma(s)
# 	- 90.11% of it is between +/- 1.65 sigma(s)
# 	- 95.45% of it is between +/- 2.00 sigma(s)
# 	- 99.73% of it is between +/- 3.00 sigma(s)

# %%
2 * stats.norm.cdf(1) -1
# Out:
# 0.68268949213708585

# %%
stats.norm.ppf(stats.norm.cdf(1))
# Out:
# 1.0

# %%
stats.norm.ppf((1+.9)/2)
# Out:
# 1.6448536269514722

# %%
model = smf.ols(formula = 'SalePrice ~ Size', data = df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.236
# Model:                            OLS   Adj. R-squared:                  0.235
# Method:                 Least Squares   F-statistic:                     297.4
# Date:                Tue, 10 Jan 2017   Prob (F-statistic):           2.67e-58
# Time:                        13:15:28   Log-Likelihood:                -1687.9
# No. Observations:                 967   AIC:                             3380.
# Df Residuals:                     965   BIC:                             3390.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      0.1551      0.084      1.842      0.066        -0.010     0.320
# Size           0.7497      0.043     17.246      0.000         0.664     0.835
# ==============================================================================
# Omnibus:                     1842.865   Durbin-Watson:                   1.704
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3398350.943
# Skew:                          13.502   Prob(JB):                         0.00
# Kurtosis:                     292.162   Cond. No.                         4.40
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = smf.ols(formula = 'SalePrice ~ 0 + Size', data = df).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.565
# Method:                 Least Squares   F-statistic:                     1255.
# Date:                Tue, 10 Jan 2017   Prob (F-statistic):          7.83e-177
# Time:                        13:18:08   Log-Likelihood:                -1689.6
# No. Observations:                 967   AIC:                             3381.
# Df Residuals:                     966   BIC:                             3386.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Size           0.8176      0.023     35.426      0.000         0.772     0.863
# ==============================================================================
# Omnibus:                     1830.896   Durbin-Watson:                   1.722
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3370566.094
# Skew:                          13.300   Prob(JB):                         0.00
# Kurtosis:                     291.005   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
def drop_outliers(df):
    print 'Dropping outliers'
    print '- n (before) =', df.shape[0]

    Q1 = df.SalePrice.quantile(.25)
    Q2 = df.SalePrice.quantile(.5)
    Q3 = df.SalePrice.quantile(.75)
    IQR = Q3 - Q1

    print '- Q1         =', Q1, '($M)'
    print '- Q2/Median  =', Q2, '($M)'
    print '- Q3         =', Q3, '($M)'

    df.drop(df[(df.SalePrice < Q1 - 1.5 * IQR) | (df.SalePrice > Q3 + 1.5 * IQR)].index, inplace = True)

    print '- n (after)  =', df.shape[0]

drop_outliers(df)
# Out:
# Dropping outliers
# - n (before) = 1000
# - Q1         = 0.8 ($M)
# - Q2/Median  = 1.1 ($M)
# - Q3         = 1.5325 ($M)
# - n (after)  = 933

# %%
model = smf.ols(formula = 'SalePrice ~ Size', data = df).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.200
# Model:                            OLS   Adj. R-squared:                  0.199
# Method:                 Least Squares   F-statistic:                     225.0
# Date:                Tue, 10 Jan 2017   Prob (F-statistic):           1.41e-45
# Time:                        13:19:57   Log-Likelihood:                -560.34
# No. Observations:                 903   AIC:                             1125.
# Df Residuals:                     901   BIC:                             1134.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      0.7082      0.032     22.152      0.000         0.645     0.771
# Size           0.2784      0.019     15.002      0.000         0.242     0.315
# ==============================================================================
# Omnibus:                       24.647   Durbin-Watson:                   1.625
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.865
# Skew:                           0.054   Prob(JB):                     2.01e-12
# Kurtosis:                       4.192   Cond. No.                         4.70
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
def drop_outliers(df):
    print 'Dropping outliers'
    print '- n (before) =', df.shape[0]

    Q1 = df.SalePrice.quantile(.25)
    Q2 = df.SalePrice.quantile(.5)
    Q3 = df.SalePrice.quantile(.75)
    IQR = Q3 - Q1

    print '- Q1         =', Q1, '($M)'
    print '- Q2/Median  =', Q2, '($M)'
    print '- Q3         =', Q3, '($M)'

    df.drop(df[(df.SalePrice < Q1 - 1.5 * IQR) | (df.SalePrice > Q3 + 1.5 * IQR)].index, inplace = True)

    print '- n (after)  =', df.shape[0]

drop_outliers(df)
# Out:
# Dropping outliers
# - n (before) = 933
# - Q1         = 0.788 ($M)
# - Q2/Median  = 1.05 ($M)
# - Q3         = 1.43 ($M)
# - n (after)  = 915

# %%
model = smf.ols(formula = 'SalePrice ~ Size', data = df).fit()

# %%
model.resid.plot(kind = 'hist', bins = 250, figsize = (8, 8))

# %%
sm.qqplot(model.resid, line = 's')

pass

# %%
sm.graphics.plot_regress_exog(model, 'Size', fig = plt.figure(figsize =(8,8)))

# %%
df = read_dataset() # reload the dataset to get our outliers back

scale_variables(df) # rescale the variables (use the function defined above)

# %%
X, y = Xy_3(df)

model = smf.OLS(y,X).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.236
# Model:                            OLS   Adj. R-squared:                  0.235
# Method:                 Least Squares   F-statistic:                     297.4
# Date:                Tue, 10 Jan 2017   Prob (F-statistic):           2.67e-58
# Time:                        13:31:12   Log-Likelihood:                -1687.9
# No. Observations:                 967   AIC:                             3380.
# Df Residuals:                     965   BIC:                             3390.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          0.1551      0.084      1.842      0.066        -0.010     0.320
# Size           0.7497      0.043     17.246      0.000         0.664     0.835
# ==============================================================================
# Omnibus:                     1842.865   Durbin-Watson:                   1.704
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3398350.943
# Skew:                          13.502   Prob(JB):                         0.00
# Kurtosis:                     292.162   Cond. No.                         4.40
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model.rsquared
# Out:
# 0.23559317159970783

# %%
y_hat = model.predict(X)

var_y_hat = sum((y - y_hat) ** 2)
var_y = sum((y - y.mean()) ** 2)

1 - var_y_hat / var_y
# Out:
# 0.23559317159970872

# %%
X, y = Xy_2(df)

model = smf.OLS(y, X).fit()

model.rsquared
# Out:
# 0.56506068149064204

# %%
y_hat = model.predict(X)

# %%
1 - sum((y - y_hat)** 2) / sum((y - y.mean())** 2)
# Out:
# 0.23290434806246241

# %%
X, y = Xy_3(df)

model = smf.OLS(y, X).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.236
# Model:                            OLS   Adj. R-squared:                  0.235
# Method:                 Least Squares   F-statistic:                     297.4
# Date:                Tue, 10 Jan 2017   Prob (F-statistic):           2.67e-58
# Time:                        13:34:43   Log-Likelihood:                -1687.9
# No. Observations:                 967   AIC:                             3380.
# Df Residuals:                     965   BIC:                             3390.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          0.1551      0.084      1.842      0.066        -0.010     0.320
# Size           0.7497      0.043     17.246      0.000         0.664     0.835
# ==============================================================================
# Omnibus:                     1842.865   Durbin-Watson:                   1.704
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3398350.943
# Skew:                          13.502   Prob(JB):                         0.00
# Kurtosis:                     292.162   Cond. No.                         4.40
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
print model.params.const
print model.bse.const
# Out:
# 0.15505177276
# 0.0841577678007

# %%
model.tvalues.const
# Out:
# 1.8423940749846963

# %%
t = (model.params.const - 0) / model.bse.const

t
# Out:
# 1.8423940749846963

# %%
model.pvalues.const
# Out:
# 0.065724161073172721

# %%
print 'Degrees of freedom (df):', model.df_resid
# Out:
# Degrees of freedom (df): 965.0

# %%
model.conf_int().T.const
# Out:
# 0   -0.010102
# 1    0.320205
# Name: const, dtype: float64

# %%
z = stats.t.ppf(1 - .05 / 2, model.df_resid)

print 'Lower bound =', model.params.const - model.bse.const * z
print 'upper bound =', model.params.const + model.bse.cpmst * z
# Out:
# Lower bound = -0.01010156253
# upper bound =
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-27970f85b1c2> in <module>()
#       2
#       3 print 'Lower bound =', model.params.const - model.bse.const * z
# ----> 4 print 'upper bound =', model.params.const + model.bse.cpmst * z
#
# /Users/samuelleichman/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'cpmst'
